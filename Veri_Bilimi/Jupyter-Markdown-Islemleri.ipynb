# %% [markdown]
# **kalın**
#
# _italik_
#
# **Sıralı Liste**
#
# 1. Masa
# 2. Sandalye
# 3. Bardak
#
# **Sırasız Liste**
#
# - Masa
# - Sandalye
# - Bardak
#
# _veya_
#
# * Masa
# * Sandalye
# * Bardak
#
# **Kod Bloğu**
#
# `print()`
#
# ```python
# print("Merhaba")
#
# ```
#
# **Resim**
#
# ![image.png](attachment:a3c42943-2a47-4288-ae6a-0c9f7175855e.png)
#
# **Link**
#
# [buraya](https://www.google.com) tıklayınız
#
# **Tablo**
#
# |Sütun 1|Sütun 2|
# |---|---|
# |A|B|
# |C|D|
#
# **Görev Listesi**
#
# - [x] Görev 1
# - [] Görev 2
#
# **Formül**
#
# ${\displaystyle f(x;p)=p^{x}(1-p)^{1-x}\quad {\text{for }}x\in \{0,1\}}$
#
# ${\displaystyle \operatorname {E} \left(X\right)=p}$
#
# $\operatorname {Var} (X)=pq=p(1-p)$

# %% [markdown]
# **İçindekiler Oluşturma**

# %% [markdown]
# ## İçindekiler:
# * [Başlık-1](#baslik-1)
# * [Başlık-2](#baslik-2)

# %% [markdown]
# ## Başlık 1 <a class="anchor" id="baslik-1"></a>
#
# kod blokları...
#
# ## Başlık 2 <a class="anchor" id="baslik-2"></a>
#
# kod blokları...
